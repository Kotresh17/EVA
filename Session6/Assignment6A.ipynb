# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(32, 3, 3, border_mode='same', input_shape=(32, 32, 3))) #32 Receptive Field 3
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.12))

model.add(Convolution2D(64, 3, 3, border_mode='same')) #32 receptive field 5
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.12))

model.add(MaxPooling2D(pool_size=(2, 2))) #16 receptive field 10

model.add(Convolution2D(10, 1))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.12))

model.add(Convolution2D(64, 3, 3, border_mode='same')) #16 receptive field 12
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.12))

model.add(Convolution2D(128, 3, 3, border_mode='same')) #16 receptive field 14
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.12))

model.add(MaxPooling2D(pool_size=(2, 2))) #8 receptive field 28 

model.add(Convolution2D(10, 1))
model.add(Activation('relu'))
model.add(BatchNormalization())


model.add(Convolution2D(128, 3, 3, border_mode='same'))# 8 receptive field 30 
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.12))

model.add(Convolution2D(256, 3, 3, border_mode='same')) # 8 receptive field 32 
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.12))

model.add(MaxPooling2D(pool_size=(2, 2))) # 4 receptive field 64

model.add(Convolution2D(16, 1))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.12))

model.add(Convolution2D(128, 3, 3, border_mode='same')) # 4 receptive field 66 
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.12))

model.add(Convolution2D(128, 3, 3, border_mode='same')) # 4 receptive field 68 
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(0.12))

model.add(Convolution2D(16, 1))#4 
model.add(Activation('relu'))
model.add(BatchNormalization())

model.add(Convolution2D(128, 3, 3, border_mode='same')) # 4 receptive field 70 
model.add(Activation('relu'))
#model.add(BatchNormalization())

model.add(Convolution2D(10, 4, 4))


model.add(Flatten())
model.add(Activation('softmax'))


model.summary()

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:36: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:41: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:58: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_27 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_27 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 32, 32, 64)        18496
# _________________________________________________________________
# activation_28 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 16, 16, 10)        650
# _________________________________________________________________
# activation_29 (Activation)   (None, 16, 16, 10)        0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 16, 16, 10)        40
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 16, 16, 10)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 16, 16, 64)        5824
# _________________________________________________________________
# activation_30 (Activation)   (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 16, 16, 128)       73856
# _________________________________________________________________
# activation_31 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 8, 8, 10)          1290
# _________________________________________________________________
# activation_32 (Activation)   (None, 8, 8, 10)          0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 8, 8, 10)          40
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 8, 8, 128)         11648
# _________________________________________________________________
# activation_33 (Activation)   (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# activation_34 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 4, 4, 16)          4112
# _________________________________________________________________
# activation_35 (Activation)   (None, 4, 4, 16)          0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 4, 4, 16)          64
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 4, 4, 16)          0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 4, 4, 128)         18560
# _________________________________________________________________
# activation_36 (Activation)   (None, 4, 4, 128)         0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 4, 4, 128)         147584
# _________________________________________________________________
# activation_37 (Activation)   (None, 4, 4, 128)         0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 4, 4, 128)         512
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 4, 4, 16)          2064
# _________________________________________________________________
# activation_38 (Activation)   (None, 4, 4, 16)          0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 4, 4, 16)          64
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 4, 4, 128)         18560
# _________________________________________________________________
# activation_39 (Activation)   (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 1, 1, 10)          20490
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_40 (Activation)   (None, 10)                0
# =================================================================
# Total params: 623,118
# Trainable params: 621,158
# Non-trainable params: 1,960
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:67: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:71: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (4, 4))`

# %%
from keras.optimizers import Adam
from keras.callbacks import LearningRateScheduler
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels),callbacks=[LearningRateScheduler(scheduler, verbose=1)],verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., verbose=1, steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 390/390 [==============================] - 46s 118ms/step - loss: 1.4552 - acc: 0.4708 - val_loss: 1.5897 - val_acc: 0.4819
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0022744503.
# 390/390 [==============================] - 41s 106ms/step - loss: 1.0164 - acc: 0.6373 - val_loss: 1.2493 - val_acc: 0.5931
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0018315018.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.8337 - acc: 0.7042 - val_loss: 0.9328 - val_acc: 0.6785
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0015329586.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.7224 - acc: 0.7458 - val_loss: 0.8697 - val_acc: 0.7066
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0013181019.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.6482 - acc: 0.7710 - val_loss: 0.7478 - val_acc: 0.7370
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0011560694.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.5811 - acc: 0.7942 - val_loss: 0.8070 - val_acc: 0.7427
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0010295127.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.5309 - acc: 0.8115 - val_loss: 0.6366 - val_acc: 0.7833
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009279307.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.4856 - acc: 0.8291 - val_loss: 0.6493 - val_acc: 0.7813
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008445946.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.4509 - acc: 0.8396 - val_loss: 0.6489 - val_acc: 0.7810
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007749935.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.4117 - acc: 0.8543 - val_loss: 0.6035 - val_acc: 0.8027
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0007159905.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.3860 - acc: 0.8643 - val_loss: 0.6591 - val_acc: 0.7840
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.000665336.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.3621 - acc: 0.8730 - val_loss: 0.6039 - val_acc: 0.8015
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0006213753.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.3372 - acc: 0.8805 - val_loss: 0.6168 - val_acc: 0.8071
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005828638.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.3192 - acc: 0.8867 - val_loss: 0.5755 - val_acc: 0.8145
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005488474.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.2975 - acc: 0.8936 - val_loss: 0.5923 - val_acc: 0.8103
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005185825.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.2812 - acc: 0.8983 - val_loss: 0.5725 - val_acc: 0.8225
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.000491481.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.2631 - acc: 0.9049 - val_loss: 0.6239 - val_acc: 0.8105
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0004670715.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.2504 - acc: 0.9095 - val_loss: 0.6140 - val_acc: 0.8167
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0004449718.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.2409 - acc: 0.9130 - val_loss: 0.6025 - val_acc: 0.8182
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.000424869.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.2313 - acc: 0.9167 - val_loss: 0.6166 - val_acc: 0.8227
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0004065041.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.2175 - acc: 0.9216 - val_loss: 0.6175 - val_acc: 0.8203
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.000389661.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.2067 - acc: 0.9258 - val_loss: 0.6303 - val_acc: 0.8198
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0003741581.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.2013 - acc: 0.9279 - val_loss: 0.6318 - val_acc: 0.8189
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0003598417.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1937 - acc: 0.9313 - val_loss: 0.6137 - val_acc: 0.8261
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0003465804.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1879 - acc: 0.9312 - val_loss: 0.6086 - val_acc: 0.8237
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0003342618.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1811 - acc: 0.9348 - val_loss: 0.6294 - val_acc: 0.8203
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003227889.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1719 - acc: 0.9382 - val_loss: 0.6323 - val_acc: 0.8309
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0003120774.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1662 - acc: 0.9387 - val_loss: 0.6374 - val_acc: 0.8264
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000302054.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1611 - acc: 0.9414 - val_loss: 0.6248 - val_acc: 0.8321
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0002926544.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1544 - acc: 0.9447 - val_loss: 0.6472 - val_acc: 0.8326
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0002838221.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1514 - acc: 0.9453 - val_loss: 0.6412 - val_acc: 0.8306
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002755074.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1444 - acc: 0.9482 - val_loss: 0.6613 - val_acc: 0.8304
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.000267666.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1429 - acc: 0.9493 - val_loss: 0.6663 - val_acc: 0.8264
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0002602585.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1411 - acc: 0.9488 - val_loss: 0.6626 - val_acc: 0.8282
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.00025325.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1364 - acc: 0.9509 - val_loss: 0.6485 - val_acc: 0.8323
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002466091.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.1333 - acc: 0.9521 - val_loss: 0.6585 - val_acc: 0.8338
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0002403076.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1282 - acc: 0.9539 - val_loss: 0.6811 - val_acc: 0.8281
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0002343201.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1266 - acc: 0.9552 - val_loss: 0.6934 - val_acc: 0.8245
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0002286237.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1221 - acc: 0.9558 - val_loss: 0.7025 - val_acc: 0.8279
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0002231977.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1189 - acc: 0.9578 - val_loss: 0.6802 - val_acc: 0.8287
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0002180233.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1208 - acc: 0.9557 - val_loss: 0.6902 - val_acc: 0.8280
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0002130833.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1164 - acc: 0.9589 - val_loss: 0.6822 - val_acc: 0.8339
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0002083623.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1157 - acc: 0.9576 - val_loss: 0.6757 - val_acc: 0.8315
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0002038459.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.1111 - acc: 0.9601 - val_loss: 0.6841 - val_acc: 0.8343
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001995211.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1045 - acc: 0.9629 - val_loss: 0.7073 - val_acc: 0.8296
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001953761.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1068 - acc: 0.9613 - val_loss: 0.6871 - val_acc: 0.8340
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001913998.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.1064 - acc: 0.9613 - val_loss: 0.6982 - val_acc: 0.8324
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001875821.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.1035 - acc: 0.9625 - val_loss: 0.7132 - val_acc: 0.8307
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001839137.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0996 - acc: 0.9648 - val_loss: 0.6995 - val_acc: 0.8321
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.000180386.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.1012 - acc: 0.9638 - val_loss: 0.7122 - val_acc: 0.8301
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001769912.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0950 - acc: 0.9671 - val_loss: 0.7071 - val_acc: 0.8314
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001737217.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0955 - acc: 0.9653 - val_loss: 0.7338 - val_acc: 0.8285
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001705708.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0972 - acc: 0.9645 - val_loss: 0.7199 - val_acc: 0.8305
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001675322.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0938 - acc: 0.9664 - val_loss: 0.7234 - val_acc: 0.8345
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001646.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0929 - acc: 0.9657 - val_loss: 0.7108 - val_acc: 0.8323
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001617687.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0905 - acc: 0.9669 - val_loss: 0.7154 - val_acc: 0.8348
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001590331.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0919 - acc: 0.9668 - val_loss: 0.7160 - val_acc: 0.8335
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001563885.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0849 - acc: 0.9692 - val_loss: 0.7437 - val_acc: 0.8286
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001538304.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0854 - acc: 0.9694 - val_loss: 0.7223 - val_acc: 0.8337
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001513546.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0874 - acc: 0.9690 - val_loss: 0.7342 - val_acc: 0.8299
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001489573.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0866 - acc: 0.9686 - val_loss: 0.7422 - val_acc: 0.8330
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001466347.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0811 - acc: 0.9712 - val_loss: 0.7481 - val_acc: 0.8254
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001443835.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0831 - acc: 0.9700 - val_loss: 0.7439 - val_acc: 0.8303
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001422003.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0810 - acc: 0.9707 - val_loss: 0.7487 - val_acc: 0.8312
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001400822.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0787 - acc: 0.9721 - val_loss: 0.7379 - val_acc: 0.8338
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001380262.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0792 - acc: 0.9721 - val_loss: 0.7572 - val_acc: 0.8309
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001360297.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0762 - acc: 0.9724 - val_loss: 0.7493 - val_acc: 0.8343
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001340902.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0769 - acc: 0.9725 - val_loss: 0.7478 - val_acc: 0.8320
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001322052.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0778 - acc: 0.9720 - val_loss: 0.7527 - val_acc: 0.8331
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001303724.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0756 - acc: 0.9730 - val_loss: 0.7553 - val_acc: 0.8318
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0001285898.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0763 - acc: 0.9733 - val_loss: 0.7398 - val_acc: 0.8367
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0001268553.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0754 - acc: 0.9727 - val_loss: 0.7550 - val_acc: 0.8317
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0001251669.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0719 - acc: 0.9740 - val_loss: 0.7525 - val_acc: 0.8333
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.0001235229.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0716 - acc: 0.9742 - val_loss: 0.7612 - val_acc: 0.8332
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0001219215.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0707 - acc: 0.9745 - val_loss: 0.7834 - val_acc: 0.8311
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.0001203611.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0695 - acc: 0.9751 - val_loss: 0.7737 - val_acc: 0.8333
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.0001188401.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0685 - acc: 0.9761 - val_loss: 0.7613 - val_acc: 0.8348
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.0001173571.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0700 - acc: 0.9744 - val_loss: 0.7536 - val_acc: 0.8344
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.0001159107.
# 390/390 [==============================] - 41s 105ms/step - loss: 0.0694 - acc: 0.9759 - val_loss: 0.7655 - val_acc: 0.8319
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.0001144994.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0720 - acc: 0.9741 - val_loss: 0.7617 - val_acc: 0.8336
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.0001131222.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0679 - acc: 0.9759 - val_loss: 0.7596 - val_acc: 0.8337
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.0001117776.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0703 - acc: 0.9749 - val_loss: 0.7615 - val_acc: 0.8335
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.0001104647.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0649 - acc: 0.9771 - val_loss: 0.7575 - val_acc: 0.8341
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.0001091822.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0655 - acc: 0.9770 - val_loss: 0.7761 - val_acc: 0.8338
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.0001079292.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0663 - acc: 0.9766 - val_loss: 0.7557 - val_acc: 0.8344
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.0001067046.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0680 - acc: 0.9754 - val_loss: 0.7622 - val_acc: 0.8333
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.0001055075.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0650 - acc: 0.9764 - val_loss: 0.7815 - val_acc: 0.8324
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.0001043369.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0641 - acc: 0.9775 - val_loss: 0.7866 - val_acc: 0.8294
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.0001031921.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0642 - acc: 0.9766 - val_loss: 0.7764 - val_acc: 0.8325
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.0001020721.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0636 - acc: 0.9775 - val_loss: 0.7702 - val_acc: 0.8351
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.0001009761.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0659 - acc: 0.9766 - val_loss: 0.7688 - val_acc: 0.8365
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler setting learning rate to 9.99034e-05.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0632 - acc: 0.9775 - val_loss: 0.7799 - val_acc: 0.8350
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler setting learning rate to 9.88533e-05.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0606 - acc: 0.9786 - val_loss: 0.7704 - val_acc: 0.8396
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler setting learning rate to 9.7825e-05.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0608 - acc: 0.9789 - val_loss: 0.8003 - val_acc: 0.8310
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler setting learning rate to 9.68179e-05.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0601 - acc: 0.9788 - val_loss: 0.7839 - val_acc: 0.8356
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler setting learning rate to 9.58313e-05.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0581 - acc: 0.9801 - val_loss: 0.7852 - val_acc: 0.8379
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler setting learning rate to 9.48647e-05.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0601 - acc: 0.9789 - val_loss: 0.7893 - val_acc: 0.8346
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler setting learning rate to 9.39173e-05.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0606 - acc: 0.9782 - val_loss: 0.7773 - val_acc: 0.8352
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler setting learning rate to 9.29887e-05.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0606 - acc: 0.9781 - val_loss: 0.7820 - val_acc: 0.8362
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler setting learning rate to 9.20782e-05.
# 390/390 [==============================] - 41s 106ms/step - loss: 0.0575 - acc: 0.9798 - val_loss: 0.7845 - val_acc: 0.8359
# Model took 4131.52 seconds to train
# Accuracy on test data is: 83.59
